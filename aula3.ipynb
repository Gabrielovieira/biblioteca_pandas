# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabrielovieira/biblioteca_pandas/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
base_casa = pd.read_csv('USA_Housing.csv', sep= ',')

# %%
base_casa.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
base_casa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
base_casa.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
# %pip install plotly
# %pip install cufflinks
# %pip install chart_studio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import cufflinks as cf
import chart_studio.plotly as py
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fig = px.box(base_casa, x= 'Avg. Area Income')
fig.update_traces(line_color= 'blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(base_casa, x= 'Price')
fig.update_traces(line_color= 'blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
base_casa.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
base_casa =base_casa.rename(columns={'Avg. Area Income':'Avg_Area_Income','Avg. Area House Age':'Avg_Area_House_Age','Avg. Area Number of Rooms':'Avg_Area_Number_of_Rooms','Avg. Area Number of Bedrooms':'Avg_ Area_Number_of_Bedrooms','Area Population':'Area_Population'})

# %%
base_casa.head()
# Out:
#    Avg_Area_Income  Avg. Area_House_Age  Avg. Area_Number_of_Rooms  \
# 0     79545.458574             5.682861                   7.009188
# 1     79248.642455             6.002900                   6.730821
# 2     61287.067179             5.865890                   8.512727
# 3     63345.240046             7.188236                   5.586729
# 4     59982.197226             5.040555                   7.839388
#
#    Avg_ Area_Number_of_Bedrooms  Area_Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
base_casa =base_casa.rename(columns={'Avg. Area Income':'Avg_Area_Income','Avg. Area House Age':'Avg_Area_House_Age','Avg. Area Number of Rooms':'Avg_Area_Number_of_Rooms','Avg. Area Number of Bedrooms':'Avg_ Area_Number_of_Bedrooms','Area Population':'Area_Population'})

# %%
base_casa.head()
# Out:
#    Avg_Area_Income  Avg. Area_House_Age  Avg. Area_Number_of_Rooms  \
# 0     79545.458574             5.682861                   7.009188
# 1     79248.642455             6.002900                   6.730821
# 2     61287.067179             5.865890                   8.512727
# 3     63345.240046             7.188236                   5.586729
# 4     59982.197226             5.040555                   7.839388
#
#    Avg_ Area_Number_of_Bedrooms  Area_Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
base_casa = base_casa.rename(columns={'Avg. Area_House_Age':'Avg_Area_House_Age','Avg. Area_Number_of_Rooms':'Avg_Area_Number_of_Rooms'})
base_casa.head()
# Out:
#    Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0     79545.458574            5.682861                  7.009188
# 1     79248.642455            6.002900                  6.730821
# 2     61287.067179            5.865890                  8.512727
# 3     63345.240046            7.188236                  5.586729
# 4     59982.197226            5.040555                  7.839388
#
#    Avg_ Area_Number_of_Bedrooms  Area_Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
base_casa.drop(['Address'], axis=1, inplace=True)
base_casa.head()
# Out:
#    Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0     79545.458574            5.682861                  7.009188
# 1     79248.642455            6.002900                  6.730821
# 2     61287.067179            5.865890                  8.512727
# 3     63345.240046            7.188236                  5.586729
# 4     59982.197226            5.040555                  7.839388
#
#    Avg_ Area_Number_of_Bedrooms  Area_Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
sns.pairplot(base_casa)

# %%
base_casa.columns
# Out:
# Index(['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
#        'Avg_ Area_Number_of_Bedrooms', 'Area_Population', 'Price'],
#       dtype='object')

# %%
sns.pairplot(base_casa, x_vars=['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
       'Avg_ Area_Number_of_Bedrooms', 'Area_Population'], y_vars='Price')

# %%
base_casa.corr()
# Out:
#                               Avg_Area_Income  Avg_Area_House_Age  \
# Avg_Area_Income                      1.000000           -0.002007
# Avg_Area_House_Age                  -0.002007            1.000000
# Avg_Area_Number_of_Rooms            -0.011032           -0.009428
# Avg_ Area_Number_of_Bedrooms         0.019788            0.006149
# Area_Population                     -0.016234           -0.018743
# Price                                0.639734            0.452543
#
#                               Avg_Area_Number_of_Rooms  \
# Avg_Area_Income                              -0.011032
# Avg_Area_House_Age                           -0.009428
# Avg_Area_Number_of_Rooms                      1.000000
# Avg_ Area_Number_of_Bedrooms                  0.462695
# Area_Population                               0.002040
# Price                                         0.335664
#
#                               Avg_ Area_Number_of_Bedrooms  Area_Population  \
# ...

# %%
sns.heatmap(base_casa.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(base_casa['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
base_casa.columns
# Out:
# Index(['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
#        'Avg_ Area_Number_of_Bedrooms', 'Area_Population', 'Price'],
#       dtype='object')

# %%
x = base_casa[['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
       'Avg_ Area_Number_of_Bedrooms', 'Area_Population']]
y = base_casa['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size= 0.3, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3500, 5)
# (1500, 5)
# (3500,)
# (1500,)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm = lm.fit(X_train, y_train)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_test)

# %%
from sklearn.metrics import r2_score
r = r2_score(y_test, y_pred)

# %%
print('r_quadrado:', r)
# Out:
# r_quadrado: 0.914681849875402

# %%
import matplotlib.pyplot as plt

# %%
c = [i for i in range(1, 1501, 1)]
fig = plt.figure(figsize=(12,8))
plt.plot(c, y_test, color='blue')
plt.plot(c, y_pred, color='red')
plt.xlabel('index')
plt.ylabel('Preço do imovel')
# Out:
# Text(0, 0.5, 'Preço do imovel')

# %%
from re import A
# premissa teste
Avg_Area_Income = 50
Avg_Area_House_Age = 30
Avg_Area_Number_of_Rooms = 2
Avg_Area_Number_of_Bedrooms = 1
Area_Population = 10000
entrada = [[Avg_Area_Income, Avg_Area_House_Age, Avg_Area_Number_of_Rooms, Avg_Area_Number_of_Bedrooms, Area_Population]]
lm.predict(entrada)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([2724302.12214249])
